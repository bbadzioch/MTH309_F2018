# %%
from sympy import *
from py309.matrix_t import *
from math import sin, cos, pi

init_printing(use_latex = 'mathjax')

# %%
A = Matrix([[cos(pi/4), -sin(pi/4)], [sin(pi/4), cos(pi/4)]])
h = matrix_t(A)

# %%
B = Matrix([[1, 0], [0, -1]])
h = matrix_t(B)

# %%
C = B*A
h = matrix_t(C)

# %%
D = A*B
h = matrix_t(D)
