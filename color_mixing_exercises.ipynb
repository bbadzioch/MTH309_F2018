# %% [markdown]
#  ### <span style="color:red">**Enter your name and person number here:**</span>
#
#  # John Smith 5019-1234

# %% [markdown]
# ### <span style="color:red">**IMPORTANT: Execute the cell below before proceeding:**</span>

# %%
# %config InlineBackend.figure_format = 'retina'

from resources309 import *
get_resources("color_mixing.py", "balloon.jpg")

from os.path import join
import matplotlib.pyplot as plt
from py309.color_mixing import *
from sympy import *

init_printing(use_latex='mathjax')
# Out:
# Resource check finished.

# %% [markdown]
# # Color mixing

# %% [markdown]
# ## RGB colors

# %% [markdown]
# The RGB color model is a method of describing colors. In this model each color is represented as a mixture of three basic colors: red, green, and blue. By varying intensities of these components a variety of colors can be obtained.
#
# In many computer applications intensities of the red, green, and blue are given by integers
# in the range 0-255, where 0 is the lowest intensity and 255 is the highest. The function `color_sample()` shows the color corresponding to given RGB coordinates:

# %%
color_sample(0, 0, 0)

# %% [markdown]
# Here we import an image file we will be working with:

# %%
# import image
balloon = plt.imread(join("py309", "balloon.jpg"))

# set image size
plt.figure(figsize=(8,12))

#display image
plt.imshow(balloon)
plt.show()

# %% [markdown]
# The image is imported as an array of vectors, one vector for each image pixel. Each vector has 3 entries with RGB  coordinates of the pixel color:

# %%
balloon
# Out:
# array([[[ 30,  62, 109],
#         [ 30,  62, 109],
#         [ 30,  62, 111],
#         ...,
#         [ 17,  48,  94],
#         [ 17,  48,  94],
#         [ 17,  48,  94]],
#
#        [[ 30,  62, 109],
#         [ 31,  63, 110],
#         [ 31,  63, 112],
#         ...,
#         [ 19,  47,  94],
#         [ 18,  46,  93],
#         [ 18,  46,  93]],
#
#        [[ 31,  63, 112],
#         [ 31,  63, 112],
#         [ 31,  63, 112],
#         ...,
#         [ 21,  48,  95],
#         [ 21,  48,  95],
#         [ 20,  47,  94]],
#
#        ...,
#
#        [[ 19,  22,  31],
#         [ 19,  22,  31],
#         [ 19,  22,  31],
#         ...,
#         [ 21,  26,  19],
#         [ 42,  47,  40],
#         [ 43,  49,  39]],
#
#        [[ 18,  23,  29],
#         [ 18,  23,  29],
#         [ 18,  23,  29],
#         ...,
#         [ 13,  18,  12],
#         [ 24,  29,  22],
#         [ 27,  33,  23]],
#
#        [[ 17,  22,  26],
#         [ 18,  23,  27],
#         [ 18,  23,  27],
#         ...,
#         [ 15,  20,  14],
#         [ 20,  25,  18],
#         [ 23,  29,  19]]], dtype=uint8)

# %% [markdown]
# ## Color mixer

# %% [markdown]
# The `color_mixer()` function works as follows. It takes as its arguments a 3x3 matrix $A$ and an array representing an image. For each image pixel it takes the vector
#
# $$\mathbf{v} = \begin{bmatrix} r \\ g \\ b \\ \end{bmatrix}$$
#
# with RGB coordinates of the pixel, and replaces it with the vector $A\mathbf{v}$, which specifies the new pixel color. Then it displays the image with colors given by the vectors $A\mathbf{v}$:

# %%
A = Matrix([[1 , 0, 0.1], [1, 1.5, 0.1], [0.1, 0.3, 1]])
A
# Out:
# ⎡ 1    0   0.1⎤
# ⎢             ⎥
# ⎢ 1   1.5  0.1⎥
# ⎢             ⎥
# ⎣0.1  0.3   1 ⎦

# %%
color_mixer(A, balloon)

# %% [markdown]
# **Note.** Since valid RGB values are integers between 0 and 255, coordinates of each vector $A\mathbf{v}$
# are rounded to the nearest integer in this range. In particular, if $A\mathbf{v}$ has negative coordinates they  are rounded up to 0, and if it has coordinates exceeding 255 they are rounded down to 255.

# %% [markdown]
# ## Exercises

# %% [markdown]
# In each of the cases below find a $3\times 3$ matrix $A$ which transforms colors of image pixels as indicated. Use the function `color_mixer()` to display the resulting image of the balloon.

# %% [markdown]
# ### Exercise 1. (5 pts)
# The matrix leaves the red component unchanged and sets the other components to 0:
#
# $$A\begin{bmatrix} r \\ g \\ b \\ \end{bmatrix}  = \begin{bmatrix} r \\ 0 \\ 0 \\ \end{bmatrix} $$

# %% [markdown]
# ### Solution:

# %% [markdown]
# ### Exercise 2. (5 pts)
#
# The matrix interchanges the red component with the blue component:
#
# $$A\begin{bmatrix} r \\ g \\ b \\ \end{bmatrix}  = \begin{bmatrix} b \\ g \\ r \\ \end{bmatrix} $$

# %% [markdown]
# ### Solution:

# %% [markdown]
# ### Exercise 3. (5 pts)
# The matrix divides all components by 2:
#
# $$A\begin{bmatrix} r \\ g \\ b \\ \end{bmatrix}  = \begin{bmatrix} \frac{1}{2}r \\ \frac{1}{2}g \\ \frac{1}{2}b \\ \end{bmatrix} $$

# %% [markdown]
# ### Solution:

# %% [markdown]
# ### Exercise 4. (5 pts)
# The matrix replaces all components by their average:
#
# $$A\begin{bmatrix} r \\ g \\ b \\ \end{bmatrix}  = \begin{bmatrix} \dfrac{r+g+b}{3} \\[1mm] \dfrac{r+g+b}{3} \\[1mm] \dfrac{r+g+b}{3} \\ \end{bmatrix} $$

# %% [markdown]
# ### Solution:
